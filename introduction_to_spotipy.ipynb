# %% [markdown]
# # Spotify Low-Level Audio Dataset Construction

# %% [markdown]
# This notebook serves as a guide to create a large dataset for analysisng

# %% [markdown]
# ## 1. Imports and Authorization

# %% [markdown]
# Imports

# %%
from __future__ import print_function    # (at top of module)
import spotipy
import spotipy.util as util
import pandas as pd # for later
from spotipy.oauth2 import SpotifyClientCredentials
import json
import requests
import time
import sys

# %% [markdown]
# Authorization

# %%
# These are basically some authorization stuff
CLIENT_ID = "93e601e99a834d4888a701e8c9783963" # enter your own here
CLIENT_SECRET = "51338e1fff944e898a25bc0f0169072a" # enter your own here
URI = "https://github.com/Ata-Tuna"
token = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
cache_token = token.get_access_token
sp = spotipy.Spotify(cache_token)

# Ignore these below
# scope = 'playlist-modify-public '
# scope += 'user-library-read '
# scope += 'user-follow-read '
# scope += 'user-library-modify '
# scope += 'user-read-private '
# scope += 'user-top-read'
# AQAH-khBwOYdjuEFGw0UALYE6vdOvU13AM5cGjT-_6xVv_0SFc0NxWT9eKvmrrC_ej9D7cSHUIAOk3AeSs4iCWODzT7QKkDNFXjLtr7LB24D1qIjiN0-BleaqHUlAaatVkdzIdCJvwvRYh1aIG2YTI-NhaXdx8f0IjW3ew1Kn0FGre-P85ObxnLBs1UZklhAFficn6UXm3oTCGjyffnMIUa6xSm8O8rZpxmTA8e-PVRTVVjt-TfBCSVl4ILMvFFkl8bXOOnWwlAbzcx-H9yslMDXw_vJpZunbRVtmnbojLxqxxtt-MoVdVVtCQz3yQnk0bQq

# %%
led_zep_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'
# spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET))

results = spotify.artist_albums(led_zep_uri, album_type='album')
albums = results['items']
# while results['next']:
#     results = spotify.next(results)
#     albums.extend(results['items'])

# for album in albums:
#     print(album['name'])

# %%
albums
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
# ...

# %%
track_id = '6hu1f1cXSw7OAqhpSQ2zDy'

dazed_and_confused = spotify.audio_analysis(track_id)

# %%
type(dazed_and_confused)
dazed_and_confused['meta']['platform']
# Out:
# 'Linux'

# %%
(dazed_and_confused)
#dazed_and_confused['bars']
# Out:
# {'meta': {'analyzer_version': '4.0.0',
#   'platform': 'Linux',
#   'detailed_status': 'OK',
#   'status_code': 0,
#   'timestamp': 1444990547,
#   'analysis_time': 15.97289,
#   'input_process': 'libvorbisfile L+R 44100->22050'},
#  'track': {'num_samples': 8519532,
#   'duration': 386.37332,
#   'sample_md5': '',
#   'offset_seconds': 0,
#   'window_seconds': 0,
#   'analysis_sample_rate': 22050,
#   'analysis_channels': 1,
#   'end_of_fade_in': 0.22136,
#   'start_of_fade_out': 378.96707,
#   'loudness': -9.526,
#   'tempo': 86.762,
#   'tempo_confidence': 0.147,
#   'time_signature': 3,
#   'time_signature_confidence': 0.437,
#   'key': 2,
#   'key_confidence': 0.528,
#   'mode': 1,
#   'mode_confidence': 0.509,
# ...

# %% [markdown]
# ## 2. Find Playlist to Analyze

# %%
util.prompt_for_user_token('atatuna',
                           scope,
                           client_id=CLIENT_ID,
                           client_secret=CLIENT_SECRET,
                           redirect_uri=URI)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/oauth2.py in get_access_token(self, code, as_dict, check_cache)
#     558             )
# --> 559             response.raise_for_status()
#     560             token_info = response.json()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 400 Client Error: Bad Request for url: https://accounts.spotify.com/api/token
#
# During handling of the above exception, another exception occurred:
#
# SpotifyOauthError                         Traceback (most recent call last)
# <ipython-input-17-9da5692934bb> in <module>
# ----> 1 util.prompt_for_user_token('atatuna',
#       2                            scope,
# ...

# %%
lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET))
results = spotify.artist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print('uri: ' + track['uri'])
    print('id: ' + track['id'])
    # sp.audio_analysis(track['uri'])
    print()
# Out:
# track    : Stairway to Heaven - Remaster
# audio    : https://p.scdn.co/mp3-preview/d65345613e6e9d2b09816783b9c79793f9175a41?cid=93e601e99a834d4888a701e8c9783963
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
# uri: spotify:track:5CQ30WqJwcep0pYcV4AMNc
# id: 5CQ30WqJwcep0pYcV4AMNc
#
# track    : Immigrant Song - Remaster
# audio    : https://p.scdn.co/mp3-preview/3af933bd6e5559e983030f2de1f7576f3da1a48c?cid=93e601e99a834d4888a701e8c9783963
# cover art: https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb
# uri: spotify:track:78lgmZwycJ3nzsdgmPPGNx
# id: 78lgmZwycJ3nzsdgmPPGNx
#
# track    : Whole Lotta Love - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/428a1ee59dbf49529f4c12dfc63d01158cca60f1?cid=93e601e99a834d4888a701e8c9783963
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
# uri: spotify:track:0hCB0YR03f6AmQaHbwWDe8
# id: 0hCB0YR03f6AmQaHbwWDe8
#
# track    : Black Dog - Remaster
# ...

# %%
# shows audio analysis for the given track

# from __future__ import print_function    # (at top of module)
# from spotipy.oauth2 import SpotifyClientCredentials
# import json
# import spotipy
# import time
# import sys


# client_credentials_manager = SpotifyClientCredentials()
# sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


if len(sys.argv) > 1:
    tid = sys.argv[1]
else:
    tid = 'spotify:track:4TTV7EcfroSLWzXRY6gLv6'

start = time.time()
analysis = sp.audio_analysis(tid)
delta = time.time() - start
print(json.dumps(analysis, indent=4))
print("analysis retrieved in %.2f seconds" % (delta,))
# Out:
# ---------------------------------------------------------------------------
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-9-4f9e2d4522c4> in <module>
#      19
#      20 start = time.time()
# ---> 21 analysis = sp.audio_analysis(tid)
#      22 delta = time.time() - start
#      23 print(json.dumps(analysis, indent=4))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/client.py in audio_analysis(self, track_id)
#    1720                 - track_id - a track URI, URL or ID
#    1721         """
# -> 1722         trid = self._get_id("track", track_id)
#    1723         return self._get("audio-analysis/" + trid)
#    1724
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/client.py in _get_id(self, type, id)
#    1986
#    1987         # TODO change to a ValueError in v3
# -> 1988         raise SpotifyException(400, -1, "Unsupported URL / URI.")
#    1989
#    1990     def _get_uri(self, type, id):
#
# ...

# %%
    app.get('/get_top_artists', function(req, res) {
  console.log('top artists');

  var authOptions = {
      url: 'https://accounts.spotify.com/api/token',
      form: {
        redirect_uri: redirect_uri,
        grant_type: 'authorization_code'
      },
      headers: {
        'Authorization': 'Basic ' + (new Buffer(client_id + ':' + client_secret).toString('base64'))
      },
      json: true
    };

  request.post(authOptions, function(error, response, body) {
    console.log('request')
    if (!error && response.statusCode === 200) {

        var access_token = body.access_token,
            refresh_token = body.refresh_token;
        var options = {
          url: 'https://api.spotify.com/v1/me/top/artists',
          headers: { 'Authorization': 'Bearer ' + access_token },
          json: true
        };

        // use the access token to access the Spotify Web API
        request.get(options, function(error, response, body) {
          console.log('request 2')
          console.log(body);
        });
     }
  });
# Out:
#   File "<ipython-input-11-835d8b749d0d>", line 1
#     app.get('/get_top_artists', function(req, res) {
#                                                    ^
# SyntaxError: invalid syntax

# %%
curl -X "GET" "https://api.spotify.com/v1/audio-analysis/5CQ30WqJwcep0pYcV4AMNc" -H "Accept: application/json" -H "Content-Type: application/json" -H "Authorization: Bearer BQDA1FPNHW0ts2lwuK95PHN0c1JqVBEJJQbWCB8gHwAVHI2DFqq3pYqgCnJdZlGPPX4SaX7gpLXieJfuBR8aXPz1b3ZQdzrM1oxaZhE3ZBGA9_YXIbvA-BC9yrsscJMXHampfZ6iR4quxsmkoUW3_k4m3uOlJPEXEkx9InET6NPkE4XsiUINo8PeiVa52XWDpJAKBsl01LgNDjhOAxyeg-zbCoIM6jONxxtwc8aLcP6Ba0fL8-DDK3mcGMvGT63-Df-BbW5eSamumJ5O0ZzyasoZTbeZdDlvq_u9fhtyouycKHFgUm7Qqw"
# Out:
#   File "<ipython-input-16-d38af27204d9>", line 1
#     curl -X "GET" "https://api.spotify.com/v1/audio-analysis/5CQ30WqJwcep0pYcV4AMNc" -H "Accept: application/json" -H "Content-Type: application/json" -H "Authorization: Bearer BQDA1FPNHW0ts2lwuK95PHN0c1JqVBEJJQbWCB8gHwAVHI2DFqq3pYqgCnJdZlGPPX4SaX7gpLXieJfuBR8aXPz1b3ZQdzrM1oxaZhE3ZBGA9_YXIbvA-BC9yrsscJMXHampfZ6iR4quxsmkoUW3_k4m3uOlJPEXEkx9InET6NPkE4XsiUINo8PeiVa52XWDpJAKBsl01LgNDjhOAxyeg-zbCoIM6jONxxtwc8aLcP6Ba0fL8-DDK3mcGMvGT63-Df-BbW5eSamumJ5O0ZzyasoZTbeZdDlvq_u9fhtyouycKHFgUm7Qqw"
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3. Analyze Tracks

# %%
#client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
#sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

if len(sys.argv) > 1:
    tid = sys.argv[1]
else:
    tid = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

start = time.time()
analysis = sp.audio_analysis(tid)
delta = time.time() - start
print(json.dumps(analysis, indent=4))
print("analysis retrieved in %.2f seconds" % (delta,))
# Out:
# ---------------------------------------------------------------------------
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-7-c6bd9bfeeecc> in <module>
#       8
#       9 start = time.time()
# ---> 10 analysis = sp.audio_analysis(tid)
#      11 delta = time.time() - start
#      12 print(json.dumps(analysis, indent=4))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/client.py in audio_analysis(self, track_id)
#    1720                 - track_id - a track URI, URL or ID
#    1721         """
# -> 1722         trid = self._get_id("track", track_id)
#    1723         return self._get("audio-analysis/" + trid)
#    1724
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/client.py in _get_id(self, type, id)
#    1986
#    1987         # TODO change to a ValueError in v3
# -> 1988         raise SpotifyException(400, -1, "Unsupported URL / URI.")
#    1989
#    1990     def _get_uri(self, type, id):
#
# ...

# %%
results
# Out:
# {'tracks': [{'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#     'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#     'id': '44Ig8dzqOkvkGDzaUof9lK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
# ...

# %% [markdown]
# ### 3.1 Analyze a Single Playlist

# %% [markdown]
# Define the analysis function.

# %%
def analyze_playlist(creator, playlist_id):
    
    
    # Create empty dataframe
    playlist_features_list = ["artist", "album", "track_name", "track_id", 
                             "danceability", "energy", "key", "loudness", "mode", "speechiness",
                             "instrumentalness", "liveness", "valence", "tempo", "duration_ms", "time_signature"]
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    
    # Create empty dict
    playlist_features = {}
    
    # Loop through every track in the playlist, extract features and append the features to the playlist df
    playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
    for track in playlist:
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
        
        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
        
    return playlist_df

# %%
playlist_df = analyze_playlist(playlist_creator, playlist_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e8d5416a669b> in <module>
# ----> 1 playlist_df = analyze_playlist(playlist_creator, playlist_id)
#
# NameError: name 'playlist_creator' is not defined

# %%
playlist_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f74b40d594ec> in <module>
# ----> 1 playlist_df.head()
#
# NameError: name 'playlist_df' is not defined

# %%
playlist_df.to_csv("filename.csv", index = False)

# %% [markdown]
# ### 3.2 Analyze Multiple Playlists

# %%
playlist_dict = {
    "warm_fuzzy_feeling" : ("spotify", "37i9dQZF1DX5IDTimEWoTd"), 
    "love_songs_heart" : ("indiemono", "5KbTzqKBqxQRD8OBtJTZrS"),
    "romance_songs" : ("Susan Doles", "7sAUK3XK8NHH1s5vGcTBkF")
}

# %%
def analyze_playlist_dict(playlist_dict):
    
    # Loop through every playlist in the dict and analyze it
    for i, (key, val) in enumerate(playlist_dict.items()):
        playlist_df = analyze_playlist(*val)
        # Add a playlist column so that we can see which playlist a track belongs too
        playlist_df["playlist"] = key
        # Create or concat df
        if i == 0:
            playlist_dict_df = playlist_df
        else:
            playlist_dict_df = pd.concat([playlist_dict_df, playlist_df], ignore_index = True)
            
    return playlist_dict_df

# %%
multiple_playlist_df = analyze_playlist_dict(playlist_dict)

# %%
multiple_playlist_df.head()
# Out:
#          artist                               album  \
# 0  James Arthur              Falling Like The Stars
# 1          Lauv                     Spotify Singles
# 2  Taylor Swift  Lover (Remix) [feat. Shawn Mendes]
# 3    Ed Sheeran       Best Part of Me (feat. YEBBA)
# 4   Niall Horan             Put A Little Love On Me
#
#                                           track_name                track_id  \
# 0                             Falling Like The Stars  15xWRPHQMeqgdkGzInx3PY
# 1  I Like Me Better - Recorded at Spotify Studios...  2uQNcZYa0SEbfW4cj0d9OS
# 2                 Lover (Remix) [feat. Shawn Mendes]  3i9UVldZOE0aD0JnyfAZZ0
# 3                      Best Part of Me (feat. YEBBA)  5ug4vqGZ3eisGhY1IsziNX
# 4                            Put A Little Love On Me  1hCTxutVVYvggAQcUUUZAT
#
#    danceability  energy key  loudness mode  speechiness instrumentalness  \
# 0         0.296   0.351   6    -9.538    1       0.0351          1.5e-06
# ...

# %%
multiple_playlist_df["playlist"].value_counts()
# Out:
# love_songs_heart      100
# romance_songs          77
# warm_fuzzy_feeling     70
# Name: playlist, dtype: int64

# %%
playlist_df.to_csv("filename.csv", index = False)
